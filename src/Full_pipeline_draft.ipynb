# %% [markdown]
# <a href="https://colab.research.google.com/github/sn0wsally/self-study-Spatial-Transcriptomics/blob/main/src/Full_pipeline_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Histology-based Breast Tumor Microenvironment Prediction using Spatial Transcriptomics Supervision
#
#
# ---

# %% [markdown]
# ### 1. Project Setup

# %% [markdown]
# ##### 1.1 Install Required Packages

# %% [markdown]
# ### 2. Load Spatial Transcriptomics Data

# %% [markdown]
# ### 3. Preprocessing and Quality Control

# %% [markdown]
# ### 4. Dimensionality Reduction and Clustering

# %% [markdown]
# ### 5. Marker Gene Analysis

# %% [markdown]
# ### 6. Clinical Cluster Mapping

# %% [markdown]
# ### 7. Path Extraction from Histology Image

# %% [markdown]
# ### 8. PyTorch Dataset Construction

# %% [markdown]
# ### 9. CNN Model Definition

# %% [markdown]
# ### 10. Model Training

# %% [markdown]
# ### 11. Inference and Spatial Mask Reconstruction

# %% [markdown]
# ### 12. Clinical Validation and Interpretation

# %% [markdown]
# ### 13. Final Figures
